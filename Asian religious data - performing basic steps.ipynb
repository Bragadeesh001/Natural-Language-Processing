# %%
# for reading arff file


import numpy as np
import pandas as pd

# %%
# Reading the text file

lines=open('Complete_data .txt')

# %%
# Importing nltk

import nltk

# %%
# Tokenizer

nltk.download('punkt')
scentense=nltk.sent_tokenize(lines.read())
scentense
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\BRAG\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['0.1\n§ 1.The Buddha: "What do you think, Rahula: What is a mirror for?',
#  '"The Buddha:Rahula: "For reflection, sir.',
#  '"Rahula:The Buddha: "In the same way, Rahula, bodily acts, verbal acts, & mental acts are to be done with repeated reflection.The Buddha:"Whenever you want to perform a bodily act, you should reflect on it: \'This bodily act I want to perform — would it lead to self-affliction, to the affliction of others, or to both?',
#  "Is it an unskillful bodily act, with painful consequences, painful results?'",
#  'If, on reflection, you know that it would lead to self-affliction, to the affliction of others, or to both; it would be an unskillful bodily act with painful consequences, painful results, then any bodily act of that sort is absolutely unfit for you to do.',
# ...

# %%
# lemmatization

# %%
# 1. Cleaning the entire paragraph(special charactes)
# 2. lowering the case
# 3. splitting each scentence
# 4. using stopwords along with lemmatizer
# 5. joing those words
# 6. appending

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
lemmatizer=WordNetLemmatizer()

import re
corpus=[]
for i in range(len(scentense)):
    review=re.sub('[^a-zA-Z]',' ',scentense[i])
    review=review.lower()
    review=review.split()
    review=[lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review=' '.join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\BRAG\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\BRAG\AppData\Roaming\nltk_data...

# %%
corpus
# Out:
# ['buddha think rahula mirror',
#  'buddha rahula reflection sir',
#  'rahula buddha way rahula bodily act verbal act mental act done repeated reflection buddha whenever want perform bodily act reflect bodily act want perform would lead self affliction affliction others',
#  'unskillful bodily act painful consequence painful result',
#  'reflection know would lead self affliction affliction others would unskillful bodily act painful consequence painful result bodily act sort absolutely unfit',
#  'reflection know would cause affliction would skillful bodily act happy consequence happy result bodily act sort fit',
#  'similarly verbal act mental act',
#  'performing bodily act reflect bodily act leading self affliction affliction others',
#  'unskillful bodily act painful consequence painful result',
#  'reflection know leading self affliction affliction others give',
#  'reflection know may continue',
#  'similarly verbal act mental act',
#  'performed bodily act reflect',
# ...

# %%
# Bag of woods

from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(binary=True)

X=cv.fit_transform(corpus)
cv.vocabulary_
# Out:
# {'buddha': 801,
#  'think': 6356,
#  'rahula': 4979,
#  'mirror': 3997,
#  'reflection': 5081,
#  'sir': 5759,
#  'way': 6956,
#  'bodily': 705,
#  'act': 96,
#  'verbal': 6820,
#  'mental': 3946,
#  'done': 1882,
#  'repeated': 5190,
#  'whenever': 7000,
#  'want': 6917,
#  'perform': 4515,
#  'reflect': 5078,
#  'would': 7131,
#  'lead': 3627,
#  'self': 5555,
#  'affliction': 164,
#  'others': 4354,
#  'unskillful': 6709,
#  'painful': 4421,
#  'consequence': 1222,
#  'result': 5272,
#  'know': 3563,
#  'sort': 5879,
#  'absolutely': 36,
#  'unfit': 6648,
#  'cause': 889,
#  'skillful': 5777,
#  'happy': 2932,
#  'fit': 2493,
#  'similarly': 5725,
#  'performing': 4519,
#  'leading': 3631,
#  'give': 2758,
#  'may': 3908,
#  'continue': 1276,
#  'performed': 4517,
#  'led': 3647,
#  'confess': 1179,
#  'reveal': 5288,
#  'lay': 3622,
#  'open': 4304,
#  'teacher': 6285,
#  'knowledgeable': 3570,
#  'companion': 1105,
#  'holy': 3060,
#  'life': 3691,
#  'confessed': 1180,
# ...

# %%
X[0].toarray().size
# Out:
# 7182

# %%
# Bag of woods with max-feature

from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(binary=True,max_features=10)

X=cv.fit_transform(corpus)
cv.vocabulary_
# Out:
# {'life': 2,
#  'one': 5,
#  'lord': 3,
#  'thing': 7,
#  'heart': 1,
#  'man': 4,
#  'shall': 6,
#  'god': 0,
#  'thou': 8,
#  'thy': 9}

# %%
X[0].toarray().size
# Out:
# 10

# %%
# Bag of woods with ngram

from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(binary=True,ngram_range=(2,2))

X=cv.fit_transform(corpus)
cv.vocabulary_
# Out:
# {'buddha think': 3769,
#  'think rahula': 36202,
#  'rahula mirror': 28171,
#  'buddha rahula': 3768,
#  'rahula reflection': 28172,
#  'reflection sir': 28624,
#  'rahula buddha': 28169,
#  'buddha way': 3770,
#  'way rahula': 39711,
#  'rahula bodily': 28167,
#  'bodily act': 3077,
#  'act verbal': 362,
#  'verbal act': 38957,
#  'act mental': 350,
#  'mental act': 22342,
#  'act done': 343,
#  'done repeated': 8400,
#  'repeated reflection': 29004,
#  'reflection buddha': 28616,
#  'buddha whenever': 3771,
#  'whenever want': 40003,
#  'want perform': 39415,
#  'perform bodily': 25970,
#  'act reflect': 355,
#  'reflect bodily': 28603,
#  'act want': 364,
#  'perform would': 25976,
#  'would lead': 41625,
#  'lead self': 18920,
#  'self affliction': 30860,
#  'affliction affliction': 562,
#  'affliction others': 577,
#  'unskillful bodily': 38450,
#  'act painful': 353,
#  'painful consequence': 25356,
#  'consequence painful': 5758,
#  'painful result': 25365,
# ...

# %%
X[0].toarray().size
# Out:
# 42016

# %%
# TF-IDF

from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()
x=tfidf.fit_transform(corpus)
tfidf.vocabulary_
# Out:
# {'buddha': 801,
#  'think': 6356,
#  'rahula': 4979,
#  'mirror': 3997,
#  'reflection': 5081,
#  'sir': 5759,
#  'way': 6956,
#  'bodily': 705,
#  'act': 96,
#  'verbal': 6820,
#  'mental': 3946,
#  'done': 1882,
#  'repeated': 5190,
#  'whenever': 7000,
#  'want': 6917,
#  'perform': 4515,
#  'reflect': 5078,
#  'would': 7131,
#  'lead': 3627,
#  'self': 5555,
#  'affliction': 164,
#  'others': 4354,
#  'unskillful': 6709,
#  'painful': 4421,
#  'consequence': 1222,
#  'result': 5272,
#  'know': 3563,
#  'sort': 5879,
#  'absolutely': 36,
#  'unfit': 6648,
#  'cause': 889,
#  'skillful': 5777,
#  'happy': 2932,
#  'fit': 2493,
#  'similarly': 5725,
#  'performing': 4519,
#  'leading': 3631,
#  'give': 2758,
#  'may': 3908,
#  'continue': 1276,
#  'performed': 4517,
#  'led': 3647,
#  'confess': 1179,
#  'reveal': 5288,
#  'lay': 3622,
#  'open': 4304,
#  'teacher': 6285,
#  'knowledgeable': 3570,
#  'companion': 1105,
#  'holy': 3060,
#  'life': 3691,
#  'confessed': 1180,
# ...

# %%
X[0].toarray().shape
# Out:
# (1, 42016)

# %%
# TF-IDF with nggram

from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(ngram_range=(2,2))
x=tfidf.fit_transform(corpus)
tfidf.vocabulary_
# Out:
# {'buddha think': 3769,
#  'think rahula': 36202,
#  'rahula mirror': 28171,
#  'buddha rahula': 3768,
#  'rahula reflection': 28172,
#  'reflection sir': 28624,
#  'rahula buddha': 28169,
#  'buddha way': 3770,
#  'way rahula': 39711,
#  'rahula bodily': 28167,
#  'bodily act': 3077,
#  'act verbal': 362,
#  'verbal act': 38957,
#  'act mental': 350,
#  'mental act': 22342,
#  'act done': 343,
#  'done repeated': 8400,
#  'repeated reflection': 29004,
#  'reflection buddha': 28616,
#  'buddha whenever': 3771,
#  'whenever want': 40003,
#  'want perform': 39415,
#  'perform bodily': 25970,
#  'act reflect': 355,
#  'reflect bodily': 28603,
#  'act want': 364,
#  'perform would': 25976,
#  'would lead': 41625,
#  'lead self': 18920,
#  'self affliction': 30860,
#  'affliction affliction': 562,
#  'affliction others': 577,
#  'unskillful bodily': 38450,
#  'act painful': 353,
#  'painful consequence': 25356,
#  'consequence painful': 5758,
#  'painful result': 25365,
# ...

# %%
X[0].toarray().shape
# Out:
# (1, 42016)

# %%
# TF-IDF with max features

from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(max_features=10)
x=tfidf.fit_transform(corpus)
tfidf.vocabulary_
# Out:
# {'life': 2,
#  'one': 5,
#  'thing': 7,
#  'mind': 4,
#  'man': 3,
#  'shall': 6,
#  'god': 0,
#  'thou': 8,
#  'thy': 9,
#  'hath': 1}

# %%
X[0].toarray().size
# Out:
# 42016
